# %%
import os
import re
import json
import requests
from pathlib import Path
import datetime
import dateparser
import pandas as pd
import numpy as np
from IPython.core.display import HTML
from IPython.display import JSON

from bs4 import BeautifulSoup
from bs4.element import Tag

from utils import get_edit_pages_metadata, _update_date_column

# %% [markdown]
# ## Initialization

# %%
def pretty_json_html(data):
    json_str = json.dumps(data, indent=4, ensure_ascii=False)
    html = f"<pre>{json_str}</pre>"
    display(HTML(html))

# %%
# Main folder for data 
folder_main = "../data"
Path(folder_main).mkdir(parents=True, exist_ok=True)

today = str(datetime.datetime.today().date())
print(f'Current Datetime is {today}.')

with open('config_lang.json') as f:
    config_lang = json.load(f)

# Extend config file
config = {}
for item in config_lang:
    lang_wiki = config_lang[item]['lang_wiki']
    config_temp = {
        "path_save_pages_current": f"{folder_main}/dumps/{lang_wiki}_pages_{today}.csv",
        "path_save_pages": f"{folder_main}/{lang_wiki}_pages.csv",
        "path_save_corections": f"{folder_main}/{lang_wiki}_corrections.csv"
    }
    config[item] = {**config_lang[item], **config_temp}
config

print()
print("Config:")
pretty_json_html(config)

print()
print("Languages:")
language_dict = {v["lang_wiki"]: v["language"] for k, v in config.items()}
pretty_json_html(language_dict)

with open('metadata/languages.json', 'w', encoding='utf-8') as f:
    json.dump(language_dict, f, ensure_ascii=False, indent=4)
# Out:
# Current Datetime is 2025-06-18.
#
# Config:
# <pre>{
#     "english": {
#         "lang_wiki": "en",
#         "language": "english",
#         "page_title": "Special:RecentChanges",
#         "is_process": false,
#         "path_save_pages_current": "../data/dumps/en_pages_2025-06-18.csv",
#         "path_save_pages": "../data/en_pages.csv",
#         "path_save_corections": "../data/en_corrections.csv"
#     },
#     "czech": {
#         "lang_wiki": "cs",
#         "language": "czech",
#         "page_title": "Speciální:Poslední_změny",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/cs_pages_2025-06-18.csv",
#         "path_save_pages": "../data/cs_pages.csv",
#         "path_save_corections": "../data/cs_corrections.csv"
#     },
#     "estonian": {
#         "lang_wiki": "et",
#         "language": "estonian",
#         "page_title": "Eri:Viimased_muudatused",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/et_pages_2025-06-18.csv",
#         "path_save_pages": "../data/et_pages.csv",
#         "path_save_corections": "../data/et_corrections.csv"
#     },
#     "german": {
#         "lang_wiki": "de",
#         "language": "german",
#         "page_title": "Spezial:Letzte_%C3%84nderungen",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/de_pages_2025-06-18.csv",
#         "path_save_pages": "../data/de_pages.csv",
#         "path_save_corections": "../data/de_corrections.csv"
#     },
#     "greek": {
#         "lang_wiki": "el",
#         "language": "greek",
#         "page_title": "Ειδικό:ΠρόσφατεςΑλλαγές",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/el_pages_2025-06-18.csv",
#         "path_save_pages": "../data/el_pages.csv",
#         "path_save_corections": "../data/el_corrections.csv"
#     },
#     "icelandic": {
#         "lang_wiki": "is",
#         "language": "icelandic",
#         "page_title": "Kerfiss%C3%AD%C3%B0a:N%C3%BDlegar_breytingar",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/is_pages_2025-06-18.csv",
#         "path_save_pages": "../data/is_pages.csv",
#         "path_save_corections": "../data/is_corrections.csv"
#     },
#     "italian": {
#         "lang_wiki": "it",
#         "language": "italian",
#         "page_title": "Speciale:UltimeModifiche",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/it_pages_2025-06-18.csv",
#         "path_save_pages": "../data/it_pages.csv",
#         "path_save_corections": "../data/it_corrections.csv"
#     },
#     "latvian": {
#         "lang_wiki": "lv",
#         "language": "latvian",
#         "page_title": "Special:RecentChanges",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/lv_pages_2025-06-18.csv",
#         "path_save_pages": "../data/lv_pages.csv",
#         "path_save_corections": "../data/lv_corrections.csv"
#     },
#     "slovene": {
#         "lang_wiki": "sl",
#         "language": "slovene",
#         "page_title": "Posebno:ZadnjeSpremembe",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/sl_pages_2025-06-18.csv",
#         "path_save_pages": "../data/sl_pages.csv",
#         "path_save_corections": "../data/sl_corrections.csv"
#     },
#     "swedish": {
#         "lang_wiki": "sv",
#         "language": "swedish",
#         "page_title": "Special:Senaste_ändringar",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/sv_pages_2025-06-18.csv",
#         "path_save_pages": "../data/sv_pages.csv",
#         "path_save_corections": "../data/sv_corrections.csv"
#     },
#     "ukrainian": {
#         "lang_wiki": "uk",
#         "language": "ukrainian",
#         "page_title": "Спеціальна:Нові_редагування",
#         "is_process": true,
#         "path_save_pages_current": "../data/dumps/uk_pages_2025-06-18.csv",
#         "path_save_pages": "../data/uk_pages.csv",
#         "path_save_corections": "../data/uk_corrections.csv"
#     }
# }</pre>
# Languages:
# <pre>{
#     "en": "english",
#     "cs": "czech",
#     "et": "estonian",
#     "de": "german",
#     "el": "greek",
#     "is": "icelandic",
#     "it": "italian",
#     "lv": "latvian",
#     "sl": "slovene",
#     "sv": "swedish",
#     "uk": "ukrainian"
# }</pre>

# %%
rename_columns_pages_dataframe = {
    "rozdíl": "url_diff",
    "historie": "url_history",
    "Unterschied": "url_diff",
    "Versionen": "url_history",
    "izmaiņas": "url_diff",
    "hronoloģija": "url_history",
    "erin": "url_diff",
    "ajal": "url_history",
    "διαφ.": "url_diff",
    "ιστορ.": "url_history",
    "diff": "url_diff",
    "cron": "url_history",
    "razl": "url_diff",
    "zgod": "url_history",
    "skillnad": "url_diff",
    "historik": "url_history",
    "різн.": "url_diff",
    "історія": "url_history",
    "hist": "url_history"
}

# %% [markdown]
# ## Pages: Data

# %%
# create empty csv files for pages if it doesn't exist; 
# for first run
columns_pages = [
    'date_edit_wiki', 'date_update', 'lang', 'lang_code', 'url_diff', 'url_history', 'title',
    'url', 'author', 'tags', 'date_edit'
]

for key, value in config.items():
    if not os.path.isfile(value['path_save_pages']):
        df_empty = pd.DataFrame(list())
        df_empty.to_csv(value['path_save_pages'], index=False)

# %%
# test run for one language
language = "ukrainian"
setup = config[language]

url = f"https://{setup['lang_wiki']}.wikipedia.org/w/index.php?hidebots=1&\
hidecategorization=1&\
hideWikibase=1&\
tagfilter=newcomer+task+copyedit&\
limit=5000&days=30&\
title={setup['page_title']}&\
urlversion=2"

metadata_init = {
    "date_update": today,
    "lang": language,
    "lang_code": setup["lang_wiki"]
}

print(f"URL for {language} language: {url}")

metadata = get_edit_pages_metadata(url, metadata_init)
df_metadata = pd.DataFrame(metadata).rename(columns=rename_columns_pages_dataframe)

if not df_metadata.empty:
    _update_date_column(df_metadata, date_col_in="date_edit_wiki", date_col_out="date_edit")
    dates = sorted([i for i in df_metadata["date_edit"].unique() if i is not None])
    print("  final - # rows: {}, start-date: {}, end-date: {}".format(
        df_metadata.shape[0], min(dates), max(dates))
    )
    display(df_metadata.tail(3))
# Out:
# URL for ukrainian language: https://uk.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Спеціальна:Нові_редагування&urlversion=2
#   final - # rows: 291, start-date: 2025-05-19, end-date: 2025-06-17
#      date_edit_wiki date_update       lang lang_code  \
# 288  19 травня 2025  2025-06-18  ukrainian        uk
# 289  19 травня 2025  2025-06-18  ukrainian        uk
# 290  19 травня 2025  2025-06-18  ukrainian        uk
#
#                                               url_diff  \
# 288  /w/index.php?title=%D0%A2%D0%B5%D1%80%D0%B5%D0...
# 289  /w/index.php?title=%D0%A2%D0%B5%D1%80%D0%B5%D0...
# 290  /w/index.php?title=%D0%9C%D0%B0%D0%B1%D0%B0%D1...
#
#                                            url_history                  title  \
# 288  /w/index.php?title=%D0%A2%D0%B5%D1%80%D0%B5%D0...  Теребовлянський район
# 289  /w/index.php?title=%D0%A2%D0%B5%D1%80%D0%B5%D0...  Теребовлянський район
# 290  /w/index.php?title=%D0%9C%D0%B0%D0%B1%D0%B0%D1...                  Мабар
#
#                                                    url  \
# 288  /wiki/%D0%A2%D0%B5%D1%80%D0%B5%D0%B1%D0%BE%D0%...
# 289  /wiki/%D0%A2%D0%B5%D1%80%D0%B5%D0%B1%D0%BE%D0%...
# 290               /wiki/%D0%9C%D0%B0%D0%B1%D0%B0%D1%80
#
#                            author  \
# 288                        MrPuVo
# 289                        MrPuVo
# 290  Фаєнгольд Евеліна Миколаївна
#
#                                                   tags   date_edit
# 288  [Візуальний редактор, Редагування з мобільного...  2025-05-19
# 289  [Візуальний редактор, Редагування з мобільного...  2025-05-19
# 290  [перше редагування, Візуальний редактор, Редаг...  2025-05-19

# %%
# run for all languages (see config dictionary)

print("Support Languages:", ', '.join(list(language_dict.values())))
for language in list(config.keys())[:]:
    print(language.upper())
    setup = config[language]
            
    url = f"https://{setup['lang_wiki']}.wikipedia.org/w/index.php?hidebots=1&\
hidecategorization=1&\
hideWikibase=1&\
tagfilter=newcomer+task+copyedit&\
limit=5000&days=30&\
title={setup['page_title']}&\
urlversion=2"
    
    metadata_init = {
            "date_update": today,
            "lang": language,
            "lang_code": setup["lang_wiki"]
        }
    
    print(f"  URL for {language} language: {url}")
    
    if setup["is_process"]:
        metadata = get_edit_pages_metadata(url, metadata_init)
        df_metadata_cur = pd.DataFrame(metadata).rename(columns=rename_columns_pages_dataframe)

        if "author" in df_metadata_cur.columns:
            df_metadata_cur = df_metadata_cur[df_metadata_cur["author"].notna()].copy().reset_index(drop=True)

        if not df_metadata_cur.empty:
            _update_date_column(df_metadata_cur, date_col_in="date_edit_wiki", date_col_out="date_edit")
            print("  current - # rows: {}, start-date: {}, end-date: {}".format(
                df_metadata_cur.shape[0], 
                df_metadata_cur["date_edit"].min(), 
                df_metadata_cur["date_edit"].max()
            ))

            df_metadata_old = pd.read_csv(setup["path_save_pages"])

            df_metadata = pd.concat([df_metadata_cur, df_metadata_old], axis=0)\
                            .sort_values(["date_update", "date_edit"])\
                            .drop_duplicates(subset=["url_diff"], keep="last")\
                            .reset_index(drop=True)

            print("  final - # rows: {}, start-date: {}, end-date: {}".format(
                df_metadata.shape[0], 
                df_metadata["date_edit"].min(), 
                df_metadata["date_edit"].max()
            ))
            display(df_metadata.tail(3))
            df_metadata_cur.to_csv(setup["path_save_pages_current"], index=False)
            df_metadata.to_csv(setup["path_save_pages"], index=False)
        else:
            print("  THERE ARE NO DATA FROM THE PAST 30 DAYS.")
        print()
    else:
        print(f"  {language.title()} is not included. Check config file.")
        print()
# Out:
# Support Languages: english, czech, estonian, german, greek, icelandic, italian, latvian, slovene, swedish, ukrainian
# ENGLISH
#   URL for english language: https://en.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Special:RecentChanges&urlversion=2
#   English is not included. Check config file.
#
# CZECH
#   URL for czech language: https://cs.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Speciální:Poslední_změny&urlversion=2
#   current - # rows: 59, start-date: 2025-05-19, end-date: 2025-06-17
#   final - # rows: 538, start-date: 2024-09-29, end-date: 2025-06-17
#     date_edit_wiki date_update   lang lang_code  \
# 535    17. 6. 2025  2025-06-18  czech        cs
# 536    17. 6. 2025  2025-06-18  czech        cs
# 537    17. 6. 2025  2025-06-18  czech        cs
#
#                                               url_diff  \
# 535  /w/index.php?title=Wapiti_v%C3%BDchodn%C3%AD&c...
# 536  /w/index.php?title=SkyEurope_Airlines&curid=24...
# 537  /w/index.php?title=Hladk%C3%A9_%C5%BDivotice&c...
#
#                                            url_history               title  \
# 535  /w/index.php?title=Wapiti_v%C3%BDchodn%C3%AD&c...     Wapiti východní
# 536  /w/index.php?title=SkyEurope_Airlines&curid=24...  SkyEurope Airlines
# 537  /w/index.php?title=Hladk%C3%A9_%C5%BDivotice&c...     Hladké Životice
#
#                                  url           author  \
# 535  /wiki/Wapiti_v%C3%BDchodn%C3%AD            Emzys
# 536         /wiki/SkyEurope_Airlines  Dominik Záškoda
# 537  /wiki/Hladk%C3%A9_%C5%BDivotice       Nitram1906
#
#                                                   tags   date_edit
# 535  [editace z Vizuálního editoru, Editační tipy, ...  2025-06-17
# 536  [editace z Vizuálního editoru, Editační tipy, ...  2025-06-17
# 537  [editace z Vizuálního editoru, Editační tipy, ...  2025-06-17
# ESTONIAN
#   URL for estonian language: https://et.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Eri:Viimased_muudatused&urlversion=2
#   current - # rows: 6, start-date: 2025-06-02, end-date: 2025-06-06
#   final - # rows: 54, start-date: 2024-10-25, end-date: 2025-06-06
#    date_edit_wiki date_update      lang lang_code  \
# 51  4. juuni 2025  2025-06-18  estonian        et
# 52  5. juuni 2025  2025-06-18  estonian        et
# 53  6. juuni 2025  2025-06-18  estonian        et
#
#                                              url_diff  \
# 51  /w/index.php?title=India_pantergeko&curid=6323...
# 52  /w/index.php?title=Rippaed&curid=674836&diff=6...
# 53  /w/index.php?title=Javier_Cercas&curid=595519&...
#
#                                           url_history             title  \
# 51  /w/index.php?title=India_pantergeko&curid=6323...  India pantergeko
# 52  /w/index.php?title=Rippaed&curid=674836&action...           Rippaed
# 53  /w/index.php?title=Javier_Cercas&curid=595519&...     Javier Cercas
#
#                        url    author  \
# 51  /wiki/India_pantergeko  Ojassaar
# 52           /wiki/Rippaed  Sininine
# 53     /wiki/Javier_Cercas  Sininine
#
#                                                  tags   date_edit
# 51  [Uue kasutaja ülesanne, Uue kasutaja ülesanne:...  2025-06-04
# 52  [Visuaalmuudatus, Uue kasutaja ülesanne, Uue k...  2025-06-05
# 53  [Visuaalmuudatus, Uue kasutaja ülesanne, Uue k...  2025-06-06
# GERMAN
#   URL for german language: https://de.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Spezial:Letzte_%C3%84nderungen&urlversion=2
#   THERE ARE NO DATA FROM THE PAST 30 DAYS.
#
# GREEK
#   URL for greek language: https://el.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Ειδικό:ΠρόσφατεςΑλλαγές&urlversion=2
#   current - # rows: 20, start-date: 2025-05-22, end-date: 2025-06-16
#   final - # rows: 175, start-date: 2024-09-28, end-date: 2025-06-16
#       date_edit_wiki date_update   lang lang_code  \
# 172  14 Ιουνίου 2025  2025-06-18  greek        el
# 173  16 Ιουνίου 2025  2025-06-18  greek        el
# 174  16 Ιουνίου 2025  2025-06-18  greek        el
#
#                                               url_diff  \
# 172  /w/index.php?title=%CE%9C%CE%B9%CF%83%CF%81%CE...
# 173  /w/index.php?title=%CE%A0%CE%B1%CE%BD%CE%B1%CE...
# 174  /w/index.php?title=%CE%A0%CE%B1%CE%BB%CE%AC%CF...
#
#                                            url_history  \
# 172  /w/index.php?title=%CE%9C%CE%B9%CF%83%CF%81%CE...
# 173  /w/index.php?title=%CE%A0%CE%B1%CE%BD%CE%B1%CE...
# 174  /w/index.php?title=%CE%A0%CE%B1%CE%BB%CE%AC%CF...
#
#                        title  \
# 172           Μισραΐμ Μέμφις
# 173  Παναγία η Μυρτιδιώτισσα
# 174                   Παλάτι
#
#                                                    url      author  \
# 172  /wiki/%CE%9C%CE%B9%CF%83%CF%81%CE%B1%CE%90%CE%...     Kostivo
# 173  /wiki/%CE%A0%CE%B1%CE%BD%CE%B1%CE%B3%CE%AF%CE%...  Κισσόβρυος
# 174         /wiki/%CE%A0%CE%B1%CE%BB%CE%AC%CF%84%CE%B9  Κισσόβρυος
#
#                                                   tags   date_edit
# 172  [Οπτική επεξεργασία, Επεξεργασία από κινητό, Δ...  2025-06-14
# 173  [Οπτική επεξεργασία, Αποστολή νεοεισερχόμενου,...  2025-06-16
# 174  [Οπτική επεξεργασία, Αποστολή νεοεισερχόμενου,...  2025-06-16
# ICELANDIC
#   URL for icelandic language: https://is.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Kerfiss%C3%AD%C3%B0a:N%C3%BDlegar_breytingar&urlversion=2
#   THERE ARE NO DATA FROM THE PAST 30 DAYS.
#
# ITALIAN
#   URL for italian language: https://it.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Speciale:UltimeModifiche&urlversion=2
#   current - # rows: 267, start-date: 2025-05-19, end-date: 2025-06-18
#   final - # rows: 2836, start-date: 2024-09-28, end-date: 2025-06-18
#      date_edit_wiki date_update     lang lang_code  \
# 2833    17 giu 2025  2025-06-18  italian        it
# 2834    17 giu 2025  2025-06-18  italian        it
# 2835    18 giu 2025  2025-06-18  italian        it
#
#                                                url_diff  \
# 2833  /w/index.php?title=Nintendo_New_York&curid=146...
# 2834  /w/index.php?title=Pietro_Sterbini&curid=22589...
# 2835  /w/index.php?title=Sam_Bartram&curid=8063046&d...
#
#                                             url_history              title  \
# 2833  /w/index.php?title=Nintendo_New_York&curid=146...  Nintendo New York
# 2834  /w/index.php?title=Pietro_Sterbini&curid=22589...    Pietro Sterbini
# 2835  /w/index.php?title=Sam_Bartram&curid=8063046&a...        Sam Bartram
#
#                           url         author  \
# 2833  /wiki/Nintendo_New_York       Vukozlav
# 2834    /wiki/Pietro_Sterbini       Vukozlav
# 2835        /wiki/Sam_Bartram  Allahuakibaro
#
#                                                    tags   date_edit
# 2833  [Modifica visuale, Modifica da mobile, Modific...  2025-06-17
# 2834  [Annullato, Modifica visuale, Modifica da mobi...  2025-06-17
# 2835  [Modifica visuale, Modifica da mobile, Modific...  2025-06-18
# LATVIAN
#   URL for latvian language: https://lv.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Special:RecentChanges&urlversion=2
#   THERE ARE NO DATA FROM THE PAST 30 DAYS.
#
# SLOVENE
#   URL for slovene language: https://sl.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Posebno:ZadnjeSpremembe&urlversion=2
#   current - # rows: 6, start-date: 2025-05-21, end-date: 2025-06-16
#   final - # rows: 34, start-date: 2024-10-05, end-date: 2025-06-16
#     date_edit_wiki date_update     lang lang_code  \
# 31    22. maj 2025  2025-06-18  slovene        sl
# 32    22. maj 2025  2025-06-18  slovene        sl
# 33  16. junij 2025  2025-06-18  slovene        sl
#
#                                              url_diff  \
# 31  /w/index.php?title=%C5%A0panska_knji%C5%BEevno...
# 32  /w/index.php?title=Pape%C5%BEinja_Ivana&curid=...
# 33  /w/index.php?title=Tadej_Poga%C4%8Dar&curid=46...
#
#                                           url_history                title  \
# 31  /w/index.php?title=%C5%A0panska_knji%C5%BEevno...  Španska književnost
# 32  /w/index.php?title=Pape%C5%BEinja_Ivana&curid=...      Papežinja Ivana
# 33  /w/index.php?title=Tadej_Poga%C4%8Dar&curid=46...        Tadej Pogačar
#
#                                     url             author  \
# 31  /wiki/%C5%A0panska_knji%C5%BEevnost  Ostrorogi Jelen 1
# 32           /wiki/Pape%C5%BEinja_Ivana  Ostrorogi Jelen 1
# 33             /wiki/Tadej_Poga%C4%8Dar  Ostrorogi Jelen 1
#
#                                                  tags   date_edit
# 31  [vizualno urejanje, mobilno urejanje, mobilno ...  2025-05-22
# 32  [vizualno urejanje, mobilno urejanje, mobilno ...  2025-05-22
# 33  [vizualno urejanje, mobilno urejanje, mobilno ...  2025-06-16
# SWEDISH
#   URL for swedish language: https://sv.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Special:Senaste_ändringar&urlversion=2
#   current - # rows: 103, start-date: 2025-05-19, end-date: 2025-06-18
#   final - # rows: 358, start-date: 2024-09-29, end-date: 2025-06-18
#     date_edit_wiki date_update     lang lang_code  \
# 355   18 juni 2025  2025-06-18  swedish        sv
# 356   18 juni 2025  2025-06-18  swedish        sv
# 357   18 juni 2025  2025-06-18  swedish        sv
#
#                                               url_diff  \
# 355  /w/index.php?title=Camp_Sweden&curid=271219&di...
# 356  /w/index.php?title=Kortes_tredje_lag_om_skenba...
# 357  /w/index.php?title=Dalm%C3%A5lare&curid=8597&d...
#
#                                            url_history  \
# 355  /w/index.php?title=Camp_Sweden&curid=271219&ac...
# 356  /w/index.php?title=Kortes_tredje_lag_om_skenba...
# 357  /w/index.php?title=Dalm%C3%A5lare&curid=8597&a...
#
#                                     title  \
# 355                           Camp Sweden
# 356  Kortes tredje lag om skenbar rörelse
# 357                             Dalmålare
#
#                                                  url              author  \
# 355                                /wiki/Camp_Sweden  Mother of all evil
# 356  /wiki/Kortes_tredje_lag_om_skenbar_r%C3%B6relse  Mother of all evil
# 357                             /wiki/Dalm%C3%A5lare  Mother of all evil
#
#                                                   tags   date_edit
# 355  [VE, Mobilredigering, Redigering via mobilsajt...  2025-06-18
# 356  [VE, Mobilredigering, Redigering via mobilsajt...  2025-06-18
# 357  [VE, Mobilredigering, Redigering via mobilsajt...  2025-06-18
# UKRAINIAN
#   URL for ukrainian language: https://uk.wikipedia.org/w/index.php?hidebots=1&hidecategorization=1&hideWikibase=1&tagfilter=newcomer+task+copyedit&limit=5000&days=30&title=Спеціальна:Нові_редагування&urlversion=2
#   current - # rows: 291, start-date: 2025-05-19, end-date: 2025-06-17
#   final - # rows: 1952, start-date: 2024-09-28, end-date: 2025-06-17
#       date_edit_wiki date_update       lang lang_code  \
# 1949  17 червня 2025  2025-06-18  ukrainian        uk
# 1950  17 червня 2025  2025-06-18  ukrainian        uk
# 1951  17 червня 2025  2025-06-18  ukrainian        uk
#
#                                                url_diff  \
# 1949  /w/index.php?title=%D0%A1%D1%82%D1%80%D0%B0%D0...
# 1950  /w/index.php?title=%D0%A4%D0%B5%D0%BD%D0%B5%D1...
# 1951  /w/index.php?title=%D0%A7%D0%B5%D1%80%D0%B2%D0...
#
#                                             url_history  \
# 1949  /w/index.php?title=%D0%A1%D1%82%D1%80%D0%B0%D0...
# 1950  /w/index.php?title=%D0%A4%D0%B5%D0%BD%D0%B5%D1...
# 1951  /w/index.php?title=%D0%A7%D0%B5%D1%80%D0%B2%D0...
#
#                              title  \
# 1949          Страговський стадіон
# 1950  Фенербахче (спортивний клуб)
# 1951       Червона гвардія Донбасу
#
#                                                     url  \
# 1949  /wiki/%D0%A1%D1%82%D1%80%D0%B0%D0%B3%D0%BE%D0%...
# 1950  /wiki/%D0%A4%D0%B5%D0%BD%D0%B5%D1%80%D0%B1%D0%...
# 1951  /wiki/%D0%A7%D0%B5%D1%80%D0%B2%D0%BE%D0%BD%D0%...
#
#                                          author  \
# 1949                                Anna Lozian
# 1950                                Anna Lozian
# 1951  Городоцька центральна публічна бібліотека
#
#                                                    tags   date_edit
# 1949  [Візуальний редактор, Завдання новачку, Завдан...  2025-06-17
# 1950  [Візуальний редактор, Завдання новачку, Завдан...  2025-06-17
# 1951  [Візуальний редактор, Завдання новачку, Завдан...  2025-06-17

# %% [markdown]
# ## Pages: Statistics

# %%
df_list = []
for i in sorted(os.listdir(folder_main)):
    if i.split('.')[-1]=='csv' and 'pages' in i:
        df_temp = pd.read_csv(os.path.join(folder_main, i))
        print(f"{i}, # rows: {df_temp.shape[0]}")
        df_list.append(df_temp)

df_pages_all = pd.concat(df_list, axis=0).reset_index(drop=True)

df_num_pages = df_pages_all['lang'].value_counts().reset_index()\
                                   .rename(columns={'index': 'language', 'lang': '# pages'})

with open('metadata/pages.json', 'w', encoding='utf-8') as f:
    json.dump(df_num_pages.to_dict('records'), f, ensure_ascii=False, indent=4)
# Out:
# cs_pages.csv, # rows: 538
# de_pages.csv, # rows: 1706
# el_pages.csv, # rows: 175
# en_pages.csv, # rows: 9842
# et_pages.csv, # rows: 54
# is_pages.csv, # rows: 0
# it_pages.csv, # rows: 2836
# lv_pages.csv, # rows: 20
# sl_pages.csv, # rows: 34
# sv_pages.csv, # rows: 358
# uk_pages.csv, # rows: 1952

# %%
df_pages_all.groupby(['lang', 'date_update'], dropna=False)['lang_code'].count()[:]['ukrainian']
# Out:
# date_update
# 2024-10-28    146
# 2024-11-06     63
# 2024-11-10    110
# 2024-11-25     76
# 2024-12-16     75
# 2025-01-15    216
# 2025-02-15    307
# 2025-03-14    122
# 2025-04-12     18
# 2025-04-17    153
# 2025-05-04     88
# 2025-05-13    287
# 2025-06-18    291
# Name: lang_code, dtype: int64

# %%
print("start-date: {}, end-date: {}".format(
    df_pages_all[df_pages_all['date_edit'].notna()]['date_edit'].min(),
    df_pages_all[df_pages_all['date_edit'].notna()]['date_edit'].max()
))

df_pages_all[df_pages_all['date_edit'].isna()]['lang'].value_counts()
# df_pages_all['date_edit'].value_counts(dropna=False).sort_index()[:]
# Out:
# start-date: 2024-09-28, end-date: 2025-06-18
# latvian    20
# Name: lang, dtype: int64

# %% [markdown]
# ## Data: Corrections Extraction

# %%
# create empty csv files for corrections if it doesn't exist; 
# for first run
columns_corrections = [
    'delitions', 'n_del', 'text_del', 'text_del_tag', 'insertions', 'n_ins', 'text_ins',
    'text_ins_tag', 'diff_url', 'diff_page'
]
for key, value in config.items():
    if not os.path.isfile(value['path_save_corections']):
        df_empty = pd.DataFrame(list(), columns=columns_corrections)
        df_empty.to_csv(value['path_save_corections'], index=False)

# %%
# test API
session = requests.Session()
api_url = "https://uk.wikipedia.org/w/api.php"

PARAMS = {
    'action': "compare",
    'format': "json",
    'prop': "diff|diffsize|user|size|comment",
    'fromrev': 43736886, #42726929,
    'torev': 41719237, #43671592
}

response = session.get(url=api_url, params=PARAMS).json()
# print(response.keys())
display(pd.json_normalize(response['compare']))
HTML(response['compare']['*'])
# Out:
#    fromsize       fromuser  fromuserid  \
# 0     12386  MinecAnton209      774975
#
#                                          fromcomment  \
# 0  Виправлені орфографчні помилки, перефразування...
#
#                                    fromparsedcomment  tosize       touser  \
# 0  Виправлені орфографчні помилки, перефразування...   12145  Бучач-Львів
#
#    touserid tocomment toparsedcomment  diffsize  \
# 0    164714                               32123
#
#                                                    *
# 0  <tr>\n  <td colspan="2" class="diff-lineno">Ря...
# <tr>
#   <td colspan="2" class="diff-lineno">Рядок 1:</td>
#   <td colspan="2" class="diff-lineno">Рядок 1:</td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><div>{{помилки}}{{стиль}}</div></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><div>{{помилки}}{{стиль}}</div></td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><div>{{футболіст}}</div></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><div>{{футболіст}}</div></td>
# </tr>
# <tr>
#   <td class="diff-marker" data-marker="−"></td>
#   <td class="diff-deletedline diff-side-deleted"><div>'''Єрген Юве'''&amp;nbsp;({{lang-no|Jørgen Juve}};<del class="diffchange diffchange-inline"> </del>22 листопада 1906, [[Порсгрунн]]&amp;nbsp;— 12 квітня 1983 року, [[Осло]])&amp;nbsp;— норвезький футболіст, журналіст та письменник. Кращий бомбардир збірної Норвегії з футболу за всю її історію, який забив 33 м'ячі в 45 матчах. Бронзовий призер літніх Олімпійських ігор 1936 року з футболу (капітан збірної). Грав на трьох позиціях: атакуючого, півзахисника та захисника. Як журналіст працював у виданнях «[[Dagbladet]]» та «[[Tidens Tegn]]», написав декілька книжок на спортивну тематику.</div></td>
#   <td class="diff-marker" data-marker="+"></td>
#   <td class="diff-addedline diff-side-added"><div>'''Єрген Юве'''&amp;nbsp;({{lang-no|Jørgen Juve}};<ins class="diffchange diffchange-inline">&amp;nbsp;</ins>22 листопада 1906, [[Порсгрунн]]&amp;nbsp;— 12 квітня 1983 року, [[Осло]])&amp;nbsp;— норвезький футболіст, журналіст та письменник. Кращий бомбардир збірної Норвегії з футболу за всю її історію, який забив 33 м'ячі в 45 матчах. Бронзовий призер літніх Олімпійських ігор 1936 року з футболу (капітан збірної). Грав на трьох позиціях: атакуючого, півзахисника та захисника. Як журналіст працював у виданнях «[[Dagbladet]]» та «[[Tidens Tegn]]», написав декілька книжок на спортивну тематику.</div></td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><br /></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><br /></td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><div>== Біографія ==</div></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><div>== Біографія ==</div></td>
# </tr>
# <tr>
#   <td colspan="2" class="diff-empty diff-side-deleted"></td>
#   <td class="diff-marker" data-marker="+"></td>
#   <td class="diff-addedline diff-side-added"><div>Єрген Юве народився 22 листопада 1906 року в місті Порсгрун.</div></td>
# </tr>
# <tr>
#   <td class="diff-marker" data-marker="−"></td>
#   <td class="diff-deletedline diff-side-deleted"><br /></td>
#   <td colspan="2" class="diff-empty diff-side-added"></td>
# </tr>
# <tr>
#   <td class="diff-marker" data-marker="−"></td>
#   <td class="diff-deletedline diff-side-deleted"><div>=== Народження ===</div></td>
#   <td colspan="2" class="diff-empty diff-side-added"></td>
# </tr>
# <tr>
#   <td class="diff-marker" data-marker="−"></td>
#   <td class="diff-deletedline diff-side-deleted"><div>Народився Йорген Юве 22 листопада 1096 року в м. [[Порсгрунн]], [[Норвегія]].</div></td>
#   <td colspan="2" class="diff-empty diff-side-added"></td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><br /></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><br /></td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><div>=== Спортивная кар'єра ===</div></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><div>=== Спортивная кар'єра ===</div></td>
# </tr>
# <tr>
#   <td colspan="2" class="diff-lineno">Рядок 12:</td>
#   <td colspan="2" class="diff-lineno">Рядок 10:</td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><div>==== Виступи за клуби ====</div></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><div>==== Виступи за клуби ====</div></td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><br /></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><br /></td>
# </tr>
# <tr>
#   <td class="diff-marker" data-marker="−"></td>
#   <td class="diff-deletedline diff-side-deleted"><div>Почав грати в футбол за команду «Уредд» із Порсгрунна у віці 16 років. В 1926 <del class="diffchange diffchange-inline">років</del> переїхав в [[Осло]], де став гравцем «Люни». В 1928 році команда Юве пройшла у фінал Кубка Норвегії, але під час вирішальної гри програла «Ерн-Хортену». В сезоні 1930/1931 Юве <del class="diffchange diffchange-inline">виступав</del> за кордоном, <del class="diffchange diffchange-inline">зігравши</del> 12 матчів за швейцарський «Базель» та <del class="diffchange diffchange-inline">забивши</del> за нього 10 голів.</div></td>
#   <td class="diff-marker" data-marker="+"></td>
#   <td class="diff-addedline diff-side-added"><div>Почав грати в футбол за команду «Уредд» із Порсгрунна у віці 16 років. В 1926 <ins class="diffchange diffchange-inline">роув</ins> переїхав в [[Осло]], де став гравцем «Люни». В 1928 році команда Юве пройшла у фінал Кубка Норвегії, але під час вирішальної гри програла «Ерн-Хортену». В сезоні 1930/1931 Юве <ins class="diffchange diffchange-inline">виступив</ins> за кордоном, <ins class="diffchange diffchange-inline">зіграв</ins> 12 матчів за швейцарський «Базель» та <ins class="diffchange diffchange-inline">забив</ins> за нього 10 голів.</div></td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><br /></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><br /></td>
# </tr>
# <tr>
#   <td class="diff-marker" data-marker="−"></td>
#   <td class="diff-deletedline diff-side-deleted"><div>З 1928 по 1937 роки Йерген Юве грав і за збірну Норвегії, за яку провів 45 матчів, забивши 33 голи, став найрезультативнішим гравцем національної команди за всю її історію. Він дебютував у матчі проти Фінляндії у червні 1928 року, а останню гру провів проти Данії в червні 1937. Свій перший гол Юве забив в червні 1929 року граючи проти [[Голландія|Голландії]], оформив у тій ж грі хет-трик. Уже в наступних семи матчах він збільшив лік своїх забитих голів до 16.<del class="diffchange diffchange-inline"> </del>У 22 матчах Юве виступав на позиції атакуючого, під час інших 23 ігор&amp;nbsp;— на позиції захисника <del class="diffchange diffchange-inline">та</del> півзахисника (на правому фланзі і в центрі). В 23 матчах Юве виводив збірну будучи капітаном команди.</div></td>
#   <td class="diff-marker" data-marker="+"></td>
#   <td class="diff-addedline diff-side-added"><div>З 1928 по 1937 роки Йерген Юве грав і за збірну Норвегії, за яку провів 45 матчів, забивши 33 голи, став найрезультативнішим гравцем національної команди за всю її історію. Він дебютував у матчі проти Фінляндії у червні 1928 року, а останню гру провів проти Данії в червні 1937. Свій перший гол Юве забив в червні 1929 року граючи проти [[Голландія|Голландії]], оформив у тій ж грі хет-трик. Уже в наступних семи матчах він збільшив лік своїх забитих голів до 16.</div></td>
# </tr>
# <tr>
#   <td colspan="2" class="diff-empty diff-side-deleted"></td>
#   <td class="diff-marker" data-marker="+"></td>
#   <td class="diff-addedline diff-side-added"><div>У 22 матчах Юве виступав на позиції атакуючого, під час інших 23 ігор&amp;nbsp;— на позиції захисника <ins class="diffchange diffchange-inline">чи</ins> півзахисника (на правому фланзі і в центрі). В 23 матчах Юве виводив збірну будучи капітаном команди.</div></td>
# </tr>
# <tr>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-deleted"><br /></td>
#   <td class="diff-marker"></td>
#   <td class="diff-context diff-side-added"><br /></td>
# </tr>
# <tr>
#   <td class="diff-marker" data-marker="−"></td>
#   <td class="diff-deletedline diff-side-deleted"><div>Юве був кап

# %%
def _add_tag(text_obj, cnt_input, tag_find, tag_wrap):
    """
    """
    text_temp = text_obj
    cnt = 0
    while cnt != cnt_input:
        text_init = text_temp.find_next(tag_find, {"class": "diffchange diffchange-inline"})
        text_temp.insert_before(tag_wrap)
        text_temp.insert_after(tag_wrap)
        text_temp = text_init
        cnt += 1
    return text_obj

def get_corrections(content, init_dict):
    """
    """
    content_obj = BeautifulSoup(content)

    results_list = []
    for row in content_obj.find_all('tr'):
        results_dict = {}
        before_obj = row.find("td", {"class": "diff-deletedline"})
        after_obj = row.find("td", {"class": "diff-addedline"})
#         print('b', before_obj)
#         print('a', after_obj)
    
        if isinstance(before_obj, Tag):
            text_deletions = before_obj.get_text()
            deletions_obj = before_obj.find_all("del", {"class": "diffchange diffchange-inline"})
            deletions = [i.contents for i in deletions_obj]
            n_deletions = len(deletions)
            tb = _add_tag(before_obj, cnt_input=n_deletions+1, tag_find="del", tag_wrap="{:-:}").get_text()
            status_b = True
        else:
            status_b = False
            
        if isinstance(after_obj, Tag):
            text_insertions = after_obj.get_text()
            insertions_obj = after_obj.find_all("ins", {"class": "diffchange diffchange-inline"})
            insertions = [i.contents for i in insertions_obj]
            n_insertions = len(insertions)
            ta = _add_tag(after_obj, cnt_input=n_insertions+1, tag_find="ins", tag_wrap="{:+:}").get_text()
            status_a = True
        else:
            status_a = False
        
        if status_b and status_a:
            results_dict['delitions'] = deletions
            results_dict['n_del'] = n_deletions
            results_dict['text_del'] = text_deletions
            results_dict['text_del_tag'] = tb
            results_dict['insertions'] = insertions
            results_dict['n_ins'] = n_insertions
            results_dict['text_ins'] = text_insertions
            results_dict['text_ins_tag'] = ta

            results_list.append({**results_dict, **init_dict})

    return results_list

# %%
pd.DataFrame(get_corrections(response['compare']['*'], {'date': 'x'}))
# Out:
#                                             delitions  n_del  \
# 0                                               [[ ]]      1
# 1        [[років], [виступав], [зігравши], [забивши]]      4
# 2                                         [[ ], [та]]      2
# 3   [[[[Літні Олімпійські ігри 1936|], []]], [[[Бе...      8
# 4                                 [[Вінгео], [читав]]      2
# 5   [[[[Базель|], []]], [ З], [та], [ рік редактор...      9
# 6                                        [[декілька]]      1
# 7                                       [[ ], [вела]]      2
# 8                                               [[ ]]      1
# 9                    [[[[Друга світова війна|], []]]]      2
# 10                      [[м. [[], []], [[Норвегія]]]]      2
#
#                                              text_del  \
# 0   '''Єрген Юве'''&nbsp;({{lang-no|Jørgen Juve}};...
# 1   Почав грати в футбол за команду «Уредд» із Пор...
# 2   З 1928 по 1937 роки Йерген Юве грав і за збірн...
# 3   Юве був капітаном норвезької команди і на [[Лі...
# 4   Футбольні експерти-сучасники називали Юве одни...
# 5   Юве вивчився на юриста в [[Базель|Базелі]] в 1...
# 6   Йорґен Юве написав декілька книг на спортивну ...
# 7   Батько&nbsp;— Уле Мартін Юве, дубильщик по про...
# 8   Йорген&nbsp;— старший із шести дітей в сім'ї, ...
# 9   Під час [[Друга світова війна|Другої сівтової ...
# 10  Йоген Юве помер у 1983 році в м. [[Осло]], [[Н...
#
#                                          text_del_tag  \
# 0   '''Єрген Юве'''&nbsp;({{lang-no|Jørgen Juve}};...
# 1   Почав грати в футбол за команду «Уредд» із Пор...
# 2   З 1928 по 1937 роки Йерген Юве грав і за збірн...
# 3   Юве був капітаном норвезької команди і на {:-:...
# 4   Футбольні експерти-сучасники називали Юве одни...
# 5   Юве вивчився на юриста в {:-:}[[Базель|{:-:}Ба...
# 6   Йорґен Юве написав {:-:}декілька{:-:} книг на ...
# 7   Батько&nbsp;— Уле Мартін Юве, дубильщик по про...
# 8   Йорген&nbsp;— старший із шести дітей в сім'ї, ...
# 9   Під час {:-:}[[Друга світова війна|{:-:}Другої...
# 10  Йоген Юве помер у 1983 році в {:-:}м. [[{:-:}О...
#
#                                  insertions  n_ins  \
# 0                                [[&nbsp;]]      1
# 1   [[роув], [виступив], [зіграв], [забив]]      4
# 2                                        []      0
# 3                                        []      0
# 4                       [[вінгео], [читал]]      2
# 5                                        []      0
# 6                              [[декількп]]      1
# 7                                        []      0
# 8                                        []      0
# 9                                        []      0
# 10                                    [[.]]      1
#
#                                              text_ins  \
# 0   '''Єрген Юве'''&nbsp;({{lang-no|Jørgen Juve}};...
# 1   Почав грати в футбол за команду «Уредд» із Пор...
# 2   З 1928 по 1937 роки Йерген Юве грав і за збірн...
# 3   Юве був капітаном норвезької команди і на Олім...
# 4   Футбольні експерти-сучасники називали Юве одни...
# 5   Юве вивчився на юриста в Базелі в 1931 році, п...
# 6   Йорґен Юве написав декількп книг на спортивну ...
# 7   Батько&nbsp;— Уле Мартін Юве, дубильщик по про...
# 8   Йорген&nbsp;— старший із шести дітей в сім'ї, ...
# 9   Під час Другої сівтової війни служив в британс...
# 10                Йоген Юве помер у 1983 році в Осло.
#
#                                          text_ins_tag date
# 0   '''Єрген Юве'''&nbsp;({{lang-no|Jørgen Juve}};...    x
# 1   Почав грати в футбол за команду «Уредд» із Пор...    x
# 2   З 1928 по 1937 роки Йерген Юве грав і за збірн...    x
# 3   Юве був капітаном норвезької команди і на Олім...    x
# 4   Футбольні експерти-сучасники називали Юве одни...    x
# 5   Юве вивчився на юриста в Базелі в 1931 році, п...    x
# 6   Йорґен Юве написав {:+:}декількп{:+:} книг на ...    x
# 7   Батько&nbsp;— Уле Мартін Юве, дубильщик по про...    x
# 8   Йорген&nbsp;— старший із шести дітей в сім'ї, ...    x
# 9   Під час Другої сівтової війни служив в британс...    x
# 10      Йоген Юве помер у 1983 році в Осло{:+:}.{:+:}    x

# %%
pd.DataFrame(get_corrections(response['compare']['*'], {'date': 'x'})).iloc[1].values
# Out:
# array([list([['років'], ['виступав'], ['зігравши'], ['забивши']]), 4,
#        'Почав грати в футбол за команду «Уредд» із Порсгрунна у віці 16 років. В 1926 років переїхав в [[Осло]], де став гравцем «Люни». В 1928 році команда Юве пройшла у фінал Кубка Норвегії, але під час вирішальної гри програла «Ерн-Хортену». В сезоні 1930/1931 Юве виступав за кордоном, зігравши 12 матчів за швейцарський «Базель» та забивши за нього 10 голів.',
#        'Почав грати в футбол за команду «Уредд» із Порсгрунна у віці 16 років. В 1926 {:-:}років{:-:} переїхав в [[Осло]], де став гравцем «Люни». В 1928 році команда Юве пройшла у фінал Кубка Норвегії, але під час вирішальної гри програла «Ерн-Хортену». В сезоні 1930/1931 Юве {:-:}виступав{:-:} за кордоном, {:-:}зігравши{:-:} 12 матчів за швейцарський «Базель» та {:-:}забивши{:-:} за нього 10 голів.',
#        list([['роув'], ['виступив'], ['зіграв'], ['забив']]), 4,
#        'Почав грати в футбол за команду «Уредд» із Порсгрунна у віці 16 років. В 1926 роув переїхав в [[Осло]], де став гравцем «Люни». В 1928 році команда Юве пройшла у фінал Кубка Норвегії, але під час вирішальної гри програла «Ерн-Хортену». В сезоні 1930/1931 Юве виступив за кордоном, зіграв 12 матчів за швейцарський «Базель» та забив за нього 10 голів.',
#        'Почав грати в футбол за команду «Уредд» із Порсгрунна у віці 16 років. В 1926 {:+:}роув{:+:} переїхав в [[Осло]], де став гравцем «Люни». В 1928 році команда Юве пройшла у фінал Кубка Норвегії, але під час вирішальної гри програла «Ерн-Хортену». В сезоні 1930/1931 Юве {:+:}виступив{:+:} за кордоном, {:+:}зіграв{:+:} 12 матчів за швейцарський «Базель» та {:+:}забив{:+:} за нього 10 голів.',
#        'x'], dtype=object)

# %%
def parse_column_url(df):
    """
    """
    df_ = df.copy()
    df_ = df_[df_['url_diff'].notna()].copy().reset_index(drop=True)
    df_['id_cur'] = df_['url_diff'].str.split('&').apply(lambda x: [i for i in x if 'curid' in i][0]).str.split('=').str[1]
    df_['id_old'] = df_['url_diff'].str.split('&').apply(lambda x: [i for i in x if 'oldid' in i][0]).str.split('=').str[1]
    df_['id_diff'] = df_['url_diff'].str.split('&').apply(lambda x: [i for i in x if 'diff' in i][0]).str.split('=').str[1]
    return df_

def get_corrections_all(df):
    """
    """
    lang_code = df.iloc[0]['lang_code']
    session = requests.Session()
    api_url = f"https://{lang_code}.wikipedia.org/w/api.php"

    results_list = []
    for i, row in df.iterrows():
        PARAMS = {
            'action': "compare",
            'format': "json",
            'prop': "diff|diffsize|user|size|comment",
            'fromrev': row['id_old'],
            'torev': row['id_diff']
        }

        response = session.get(url=api_url, params=PARAMS).json()
        
        fromsize = int(response['compare'].get('fromsize', 0)) if 'compare' in response.keys() else 0
        tosize = int(response['compare'].get('tosize', 0)) if 'compare' in response.keys() else 0
        
        init_dict = {
            'diff_url': f"https://{row['lang_code']}.wikipedia.org" + row['url_diff'], 
            'diff_page': fromsize - tosize
        }

        response_data = get_corrections(response['compare']['*'], init_dict) if 'compare' in response.keys() else []
        results_list.extend(response_data)

    return pd.DataFrame(results_list)

# %%
# %%time

# for one language
language = 'estonian'
setup = config[language]

# old
print("OLD:")
df_correction_old = pd.read_csv(setup['path_save_corections'])
display(df_correction_old.tail(3))

# current
df_pages_cur = pd.read_csv(setup['path_save_pages_current'])
df_pages_cur = parse_column_url(df_pages_cur)
df_correction_cur = get_corrections_all(df_pages_cur)
print("NEW:")
display(df_correction_cur.tail(3))

# results
df_correction = pd.concat([df_correction_old, df_correction_cur], axis=0)\
                  .drop_duplicates(['text_del', 'text_ins', 'diff_url'], keep='first')\
                  .reset_index(drop=True)
print("RESULT:")
df_correction.tail(3)
# Out:
# OLD:
#        delitions  n_del                                           text_del  \
# 135  [['1 400']]      1  Metsad on säilinud vaid mägistes piirkondades ...
# 136           []      0  Ta on maailma kõige põhjapoolsema levikuga mad...
# 137     [['o ']]      1  Vereplasma on õrnkollakas vedelik, mis moodust...
#
#                                           text_del_tag  \
# 135  Metsad on säilinud vaid mägistes piirkondades ...
# 136  Ta on maailma kõige põhjapoolsema levikuga mad...
# 137  Vereplasma on õrnkollakas vedelik, mis moodust...
#
#                                             insertions  n_ins  \
# 135                                         [['1400']]      1
# 136  [['<ref>{{Netiviide |kuupäev=2023-07-04 |pealk...      1
# 137                                            [['°']]      1
#
#                                               text_ins  \
# 135  Metsad on säilinud vaid mägistes piirkondades ...
# 136  Ta on maailma kõige põhjapoolsema levikuga mad...
# 137  Vereplasma on õrnkollakas vedelik, mis moodust...
#
#                                           text_ins_tag  \
# 135  Metsad on säilinud vaid mägistes piirkondades ...
# 136  Ta on maailma kõige põhjapoolsema levikuga mad...
# 137  Vereplasma on õrnkollakas vedelik, mis moodust...
#
#                                               diff_url  diff_page
# 135  https://et.wikipedia.org/w/index.php?title=Jaa...         -9
# 136  https://et.wikipedia.org/w/index.php?title=Har...       -238
# 137  https://et.wikipedia.org/w/index.php?title=Ver...          0
# NEW:
#                            delitions  n_del  \
# 15                             [[.]]      1
# 16    [[jaapani], [kaldakindlustaj]]      2
# 17  [[jaapani], [ tervislikku], [ ]]      3
#
#                                              text_del  \
# 15  Aretatud on palju sorte ja need on populaarsed...
# 16  Mullatüübina eelistab jaapani enelas lubjarohk...
# 17  Pärast istutamist nõuab jaapani enelas hooldus...
#
#                                          text_del_tag  \
# 15  Aretatud on palju sorte ja need on populaarsed...
# 16  Mullatüübina eelistab {:-:}jaapani{:-:} enelas...
# 17  Pärast istutamist nõuab {:-:}jaapani{:-:} enel...
#
#                                  insertions  n_ins  \
# 15                                       []      0
# 16  [[Jaapani], [ on], [kalda kindlustaja]]      3
# 17                              [[Jaapani]]      1
#
#                                              text_ins  \
# 15  Aretatud on palju sorte ja need on populaarsed...
# 16  Mullatüübina eelistab Jaapani enelas lubjarohk...
# 17  Pärast istutamist nõuab Jaapani enelas hooldus...
#
#                                          text_ins_tag  \
# 15  Aretatud on palju sorte ja need on populaarsed...
# 16  Mullatüübina eelistab {:+:}Jaapani{:+:} enelas...
# 17  Pärast istutamist nõuab {:+:}Jaapani{:+:} enel...
#
#                                              diff_url  diff_page
# 15  https://et.wikipedia.org/w/index.php?title=Jaa...          9
# 16  https://et.wikipedia.org/w/index.php?title=Jaa...          9
# 17  https://et.wikipedia.org/w/index.php?title=Jaa...          9
# RESULT:
# CPU times: user 230 ms, sys: 16.1 ms, total: 246 ms
# Wall time: 1.76 s
#                             delitions  n_del  \
# 153                             [[.]]      1
# 154    [[jaapani], [kaldakindlustaj]]      2
# 155  [[jaapani], [ tervislikku], [ ]]      3
#
#                                               text_del  \
# 153  Aretatud on palju sorte ja need on populaarsed...
# 154  Mullatüübina eelistab jaapani enelas lubjarohk...
# 155  Pärast istutamist nõuab jaapani enelas hooldus...
#
#                                           text_del_tag  \
# 153  Aretatud on palju sorte ja need on populaarsed...
# 154  Mullatüübina eelistab {:-:}jaapani{:-:} enelas...
# 155  Pärast istutamist nõuab {:-:}jaapani{:-:} enel...
#
#                                   insertions  n_ins  \
# 153                                       []      0
# 154  [[Jaapani], [ on], [kalda kindlustaja]]      3
# 155                              [[Jaapani]]      1
#
#                                               text_ins  \
# 153  Aretatud on palju sorte ja need on populaarsed...
# 154  Mullatüübina eelistab Jaapani enelas lubjarohk...
# 155  Pärast istutamist nõuab Jaapani enelas hooldus...
#
#                                           text_ins_tag  \
# 153  Aretatud on palju sorte ja need on populaarsed...
# 154  Mullatüübina eelistab {:+:}Jaapani{:+:} enelas...
# 155  Pärast istutamist nõuab {:+:}Jaapani{:+:} enel...
#
#                                               diff_url  diff_page
# 153  https://et.wikipedia.org/w/index.php?title=Jaa...          9
# 154  https://et.wikipedia.org/w/index.php?title=Jaa...          9
# 155  https://et.wikipedia.org/w/index.php?title=Jaa...          9

# %%
# %%time
# for all languages. It processes only diff.
for language in list(config.keys())[:]:
    print(language.upper())
    setup = config[language]
    
    df_correction_old = pd.read_csv(setup['path_save_corections'])
    num_corrections_old = df_correction_old.shape[0]
    print('  Corrections Old: {}'.format(num_corrections_old))
 
    if os.path.isfile(setup['path_save_pages_current']):
        df_pages_cur = pd.read_csv(setup['path_save_pages_current'])
        df_pages_cur = parse_column_url(df_pages_cur)
        df_correction_cur = get_corrections_all(df_pages_cur)
        num_corrections_cur = df_correction_cur.shape[0]
        print('  Corrections Current: {}'.format(num_corrections_cur))

        df_correction = pd.concat([df_correction_old, df_correction_cur], axis=0)\
                          .drop_duplicates(['text_del', 'text_ins', 'diff_url'], keep='first')\
                          .reset_index(drop=True)

        num_corrections_final = df_correction.shape[0]
        print('  Corrections Final: {}'.format(num_corrections_final))
        print('  {} corrections were added.'.format(num_corrections_final-num_corrections_old))
        # update corrections files
        if num_corrections_cur>0:
            df_correction.to_csv(setup['path_save_corections'], index=False)
            print('Saved!')
            print()
    else:
        print('  Corrections Current: {}'.format(0))
        print('  Corrections Final: {}'.format(0))
        print('  {} corrections were added.'.format(0))
        print()
# Out:
# ENGLISH
#   Corrections Old: 29454
#   Corrections Current: 0
#   Corrections Final: 0
#   0 corrections were added.
#
# CZECH
#   Corrections Old: 1193
#   Corrections Current: 141
#   Corrections Final: 1330
#   137 corrections were added.
# Saved!
# ESTONIAN
#   Corrections Old: 138
#   Corrections Current: 18
#   Corrections Final: 156
#   18 corrections were added.
# Saved!
# GERMAN
#   Corrections Old: 4672
#   Corrections Current: 0
#   Corrections Final: 0
#   0 corrections were added.
#
# GREEK
#   Corrections Old: 562
#   Corrections Current: 61
#   Corrections Final: 622
#   60 corrections were added.
# Saved!
# ICELANDIC
#   Corrections Old: 0
#   Corrections Current: 0
#   Corrections Final: 0
#   0 corrections were added.
#
# ITALIAN
#   Corrections Old: 6488
#   Corrections Current: 783
#   Corrections Final: 7252
#   764 corrections were added.
# Saved!
# LATVIAN
#   Corrections Old: 75
#   Corrections Current: 0
#   Corrections Final: 0
#   0 corrections were added.
#
# SLOVENE
#   Corrections Old: 121
#   Corrections Current: 14
#   Corrections Final: 135
#   14 corrections were added.
# Saved!
# SWEDISH
#   Corrections Old: 654
#   Corrections Current: 282
#   Corrections Final: 936
#   282 corrections were added.
# Saved!
# UKRAINIAN
#   Corrections Old: 6165
#   Corrections Current: 851
#   Corrections Final: 6998
#   833 corrections were added.
# Saved!
# CPU times: user 24.8 s, sys: 1.17 s, total: 25.9 s
# Wall time: 3min 18s

# %%
# %%time
# # run corrections for all languages from scratch. It processes a full [lang]_pages.csv file.
# for language in list(config.keys())[:]:
#     print(language.upper())
#     setup = config[language]

#     df_pages_temp = pd.read_csv(setup['path_save_pages'])
#     df_pages_temp = parse_column_url(df_pages_temp)
#     print('  Input: {}'.format(df_pages_temp.shape[0]))

#     if not df_pages_temp.empty:
#         df_correction_temp = get_corrections_all(df_pages_temp)
#         print('  Output: {}'.format(df_correction_temp.shape[0]))
#         df_correction_temp.to_csv(setup['path_save_corections'], index=False)

# %% [markdown]
# ## Corrections: Statistics

# %%
df_list = []
for i in sorted(os.listdir(folder_main)):
    if i.split('.')[-1]=='csv' and 'correction' in i:
        df_temp = pd.read_csv(os.path.join(folder_main, i))
        df_temp['code_lang'] = i.split('_')[0]
        print(f"{i}, # rows: {df_temp.shape[0]}")
        df_list.append(df_temp)

df_correction_all = pd.concat(df_list, axis=0).reset_index(drop=True)

df_num_corrections = df_correction_all['code_lang'].value_counts().reset_index()\
                        .rename(columns={'index': 'language_code', 'code_lang': '# edits'})

df_num_corrections['language'] = df_num_corrections['language_code'].replace(language_dict)

with open('metadata/corrections.json', 'w', encoding='utf-8') as f:
    json.dump(df_num_corrections.to_dict('records'), f, ensure_ascii=False, indent=4)
# Out:
# cs_corrections.csv, # rows: 1330
# de_corrections.csv, # rows: 4672
# el_corrections.csv, # rows: 622
# en_corrections.csv, # rows: 29454
# et_corrections.csv, # rows: 156
# is_corrections.csv, # rows: 0
# it_corrections.csv, # rows: 7252
# lv_corrections.csv, # rows: 75
# sl_corrections.csv, # rows: 135
# sv_corrections.csv, # rows: 936
# uk_corrections.csv, # rows: 6998
